# %%
from sagemaker import get_execution_role

role = get_execution_role()
bucket='sagemaker-01182018'

# %%
# %%time
import pickle, gzip, numpy, urllib.request, json

# Load the dataset
urllib.request.urlretrieve("http://deeplearning.net/data/mnist/mnist.pkl.gz", "mnist.pkl.gz")
with gzip.open('mnist.pkl.gz', 'rb') as f:
    train_set, valid_set, test_set = pickle.load(f, encoding='latin1')
# Out:
# CPU times: user 2.42 s, sys: 464 ms, total: 2.88 s
# Wall time: 4.05 s

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (2,10)


def show_digit(img, caption='', subplot=None):
    if subplot==None:
        _,(subplot)=plt.subplots(1,1)
    imgr=img.reshape((28,28))
    subplot.axis('off')
    subplot.imshow(imgr, cmap='gray')
    plt.title(caption)

show_digit(train_set[0][32], 'This is a {}'.format(train_set[1][32]))

# %%
from sagemaker import KMeans

data_location = 's3://{}/kmeans_highlevel_example/data'.format(bucket)
output_location = 's3://{}/kmeans_example/output'.format(bucket)

print('training data will be uploaded to: {}'.format(data_location))
print('training artifacts will be uploaded to: {}'.format(output_location))

kmeans = KMeans(role=role,
                train_instance_count=2,
                train_instance_type='ml.c4.8xlarge',
                output_path=output_location,
                k=10,
                data_location=data_location)
# Out:
# training data will be uploaded to: s3://sagemaker-01182018/kmeans_highlevel_example/data
# training artifacts will be uploaded to: s3://sagemaker-01182018/kmeans_example/output
# INFO:sagemaker:Created S3 bucket: sagemaker-us-east-1-018670487324

# %%
# %%time

kmeans.fit(kmeans.record_set(train_set[0]))
# Out:
# INFO:sagemaker:Creating training-job with name: kmeans-2018-01-19-02-27-34-273
# .....................................................................
# Arguments: train
# [01/19/2018 02:33:17 INFO 140719683082048 integration.py:222] Reading default configuration from /opt/amazon/lib/python2.7/site-packages/algorithm/default-input.json: {u'_num_gpus': u'auto', u'local_lloyd_num_trials': u'auto', u'_log_level': u'info', u'_kvstore': u'auto', u'local_lloyd_init_method': u'kmeans++', u'force_dense': u'true', u'epochs': u'1', u'init_method': u'random', u'local_lloyd_tol': u'0.0001', u'local_lloyd_max_iter': u'300', u'_disable_wait_to_read': u'false', u'extra_center_factor': u'auto', u'eval_metrics': u'["msd"]', u'_num_kv_servers': u'1', u'mini_batch_size': u'5000', u'half_life_time_size': u'0', u'_num_slices': u'1'}
# [01/19/2018 02:33:17 INFO 140719683082048 integration.py:228] Reading provided configuration from /opt/ml/input/config/hyperparameters.json: {u'feature_dim': u'784', u'mini_batch_size': u'500', u'k': u'10', u'force_dense': u'True'}
# [01/19/2018 02:33:17 INFO 140719683082048 integration.py:244] Final configuration: {u'k': u'10', u'_num_gpus': u'auto', u'local_lloyd_num_trials': u'auto', u'_log_level': u'info', u'_kvstore': u'auto', u'local_lloyd_init_method': u'kmeans++', u'force_dense': u'True', u'epochs': u'1', u'init_method': u'random', u'feature_dim': u'784', u'local_lloyd_tol': u'0.0001', u'local_lloyd_max_iter': u'300', u'_disable_wait_to_read': u'false', u'extra_center_factor': u'auto', u'eval_metrics': u'["msd"]', u'_num_kv_servers': u'1', u'mini_batch_size': u'500', u'half_life_time_size': u'0', u'_num_slices': u'1'}
# [01/19/2018 02:33:18 INFO 140719683082048 utils.py:140] Launching parameter server for role scheduler
# [01/19/2018 02:33:18 INFO 140719683082048 utils.py:141] {'LANG': 'en_US.utf8', 'DMLC_INTERFACE': 'ethwe', 'SHLVL': '1', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'HOSTNAME': 'aws', 'AWS_REGION': 'us-east-1', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/15fe0803-209c-4e3a-9d3c-28c8b03cd64c', 'OMP_NUM_THREADS': '18', 'PWD': '/', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'ENVROOT': '/opt/amazon', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/amazon/bin:/opt/amazon/bin', 'SAGEMAKER_HTTP_PORT': '8080', 'HOME': '/root', 'PYTHONUNBUFFERED': 'TRUE', 'CANONICAL_ENVROOT': '/opt/amazon', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'LD_LIBRARY_PATH': '/opt/amazon/lib:/usr/local/nvidia/lib64:/opt/amazon/lib/stubs', 'MXNET_KVSTORE_BIGARRAY_BOUND': '400000000'}
# [01/19/2018 02:33:18 INFO 140719683082048 utils.py:142] envs={'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'DMLC_NUM_WORKER': '2', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'ENVROOT': '/opt/amazon', 'HOME': '/root', 'SAGEMAKER_HTTP_PORT': '8080', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/amazon/bin:/opt/amazon/bin', 'PYTHONUNBUFFERED': 'TRUE', 'CANONICAL_ENVROOT': '/opt/amazon', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'LD_LIBRARY_PATH': '/opt/amazon/lib:/usr/local/nvidia/lib64:/opt/amazon/lib/stubs', 'MXNET_KVSTORE_BIGARRAY_BOUND': '400000000', 'LANG': 'en_US.utf8', 'DMLC_INTERFACE': 'ethwe', 'SHLVL': '1', 'DMLC_PS_ROOT_URI': '10.32.0.4', 'HOSTNAME': 'aws', 'AWS_REGION': 'us-east-1', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/15fe0803-209c-4e3a-9d3c-28c8b03cd64c', 'DMLC_ROLE': 'scheduler', 'OMP_NUM_THREADS': '18', 'PWD': '/', 'DMLC_NUM_SERVER': '1', 'DMLC_PS_ROOT_PORT': '9000'}
# [01/19/2018 02:33:18 INFO 140719683082048 utils.py:140] Launching parameter server for role server
# [01/19/2018 02:33:18 INFO 140719683082048 utils.py:141] {'LANG': 'en_US.utf8', 'DMLC_INTERFACE': 'ethwe', 'SHLVL': '1', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'HOSTNAME': 'aws', 'AWS_REGION': 'us-east-1', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/15fe0803-209c-4e3a-9d3c-28c8b03cd64c', 'OMP_NUM_THREADS': '18', 'PWD': '/', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'ENVROOT': '/opt/amazon', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/amazon/bin:/opt/amazon/bin', 'SAGEMAKER_HTTP_PORT': '8080', 'HOME': '/root', 'PYTHONUNBUFFERED': 'TRUE', 'CANONICAL_ENVROOT': '/opt/amazon', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'LD_LIBRARY_PATH': '/opt/amazon/lib:/usr/local/nvidia/lib64:/opt/amazon/lib/stubs', 'MXNET_KVSTORE_BIGARRAY_BOUND': '400000000'}
# [01/19/2018 02:33:18 INFO 140719683082048 utils.py:142] envs={'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'DMLC_NUM_WORKER': '2', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'ENVROOT': '/opt/amazon', 'HOME': '/root', 'SAGEMAKER_HTTP_PORT': '8080', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/amazon/bin:/opt/amazon/bin', 'PYTHONUNBUFFERED': 'TRUE', 'CANONICAL_ENVROOT': '/opt/amazon', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'LD_LIBRARY_PATH': '/opt/amazon/lib:/usr/local/nvidia/lib64:/opt/amazon/lib/stubs', 'MXNET_KVSTORE_BIGARRAY_BOUND': '400000000', 'LANG': 'en_US.utf8', 'DMLC_INTERFACE': 'ethwe', 'SHLVL': '1', 'DMLC_PS_ROOT_URI': '10.32.0.4', 'HOSTNAME': 'aws', 'AWS_REGION': 'us-east-1', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/15fe0803-209c-4e3a-9d3c-28c8b03cd64c', 'DMLC_ROLE': 'server', 'OMP_NUM_THREADS': '18', 'PWD': '/', 'DMLC_NUM_SERVER': '1', 'DMLC_PS_ROOT_PORT': '9000'}
# [01/19/2018 02:33:18 INFO 140719683082048 utils.py:134] Environment: {'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'DMLC_PS_ROOT_PORT': '9000', 'DMLC_NUM_WORKER': '2', 'SAGEMAKER_HTTP_PORT': '8080', 'HOME': '/root', 'PYTHONUNBUFFERED': 'TRUE', 'CANONICAL_ENVROOT': '/opt/amazon', 'LD_LIBRARY_PATH': '/opt/amazon/lib:/usr/local/nvidia/lib64:/opt/amazon/lib/stubs', 'MXNET_KVSTORE_BIGARRAY_BOUND': '400000000', 'LANG': 'en_US.utf8', 'DMLC_INTERFACE': 'ethwe', 'SHLVL': '1', 'DMLC_PS_ROOT_URI': '10.32.0.4', 'AWS_REGION': 'us-east-1', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/amazon/bin:/opt/amazon/bin', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'ENVROOT': '/opt/amazon', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'OMP_NUM_THREADS': '18', 'HOSTNAME': 'aws', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/15fe0803-209c-4e3a-9d3c-28c8b03cd64c', 'DMLC_ROLE': 'worker', 'PWD': '/', 'DMLC_NUM_SERVER': '1'}
# [01/19/2018 02:33:18 INFO 140719683082048 train.py:72] Using default worker.
# [01/19/2018 02:33:19 INFO 140719683082048 data_handler_factory.py:79] Loaded iterator creator application/x-recordio-protobuf for content type ('application/x-recordio-protobuf', '1.0')
# [01/19/2018 02:33:19 INFO 140719683082048 sdk.py:138] Create Store: dist_async
# [01/19/2018 02:33:19 INFO 140719683082048 gpu.py:44] nvidia-smi took: 0.0252590179443 secs to identify 0 gpus
# [01/19/2018 02:33:19 INFO 140719683082048 sdk.py:85] Number of GPUs being used: 0
# [01/19/2018 02:33:19 INFO 140719683082048 algo.py:282] Setting up with params: {u'k': u'10', u'_num_gpus': u'auto', u'local_lloyd_num_trials': u'auto', u'_log_level': u'info', u'_kvstore': u'auto', u'local_lloyd_init_method': u'kmeans++', u'force_dense': u'True', u'epochs': u'1', u'init_method': u'random', u'feature_dim': u'784', u'local_lloyd_tol': u'0.0001', u'local_lloyd_max_iter': u'300', u'_disable_wait_to_read': u'false', u'extra_center_factor': u'auto', u'eval_metrics': u'["msd"]', u'_num_kv_servers': u'1', u'mini_batch_size': u'500', u'half_life_time_size': u'0', u'_num_slices': u'1'}
# /opt/amazon/lib/python2.7/site-packages/ai_algorithms_sdk/config/config_helper.py:180: DeprecationWarning: deprecated
#   warnings.warn("deprecated", DeprecationWarning)
# /opt/amazon/lib/python2.7/site-packages/ai_algorithms_sdk/config/config_helper.py:125: DeprecationWarning: deprecated
#   warnings.warn("deprecated", DeprecationWarning)
# [01/19/2018 02:33:19 INFO 140719683082048 sdk.py:85] Number of GPUs being used: 0
# [01/19/2018 02:33:19 INFO 140719683082048 algo.py:320] number of center slices 1
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 1, "sum": 1.0, "min": 1}, "Number of Batches Since Last Reset": {"count": 1, "max": 1, "sum": 1.0, "min": 1}, "Number of Records Since Last Reset": {"count": 1, "max": 500, "sum": 500.0, "min": 500}, "Total Batches Seen": {"count": 1, "max": 1, "sum": 1.0, "min": 1}, "Total Records Seen": {"count": 1, "max": 500, "sum": 500.0, "min": 500}, "Max Records Seen Between Resets": {"count": 1, "max": 500, "sum": 500.0, "min": 500}, "Reset Count": {"count": 1, "max": 0, "sum": 0.0, "min": 0}}, "EndTime": 1516329199.906877, "Dimensions": {"Host": "algo-1", "Meta": "init_train_data_iter", "Operation": "training", "Algorithm": "AWS/KMeansWebscale"}, "StartTime": 1516329199.906849}
#
# [01/19/2018 02:33:20 INFO 140719683082048 algo.py:451] Iter 10: Short term msd 31.886497. Long term msd 33.676006
# [01/19/2018 02:33:20 INFO 140719683082048 algo.py:451] Iter 20: Short term msd 29.844153. Long term msd 30.591699
# [01/19/2018 02:33:20 INFO 140719683082048 algo.py:451] Iter 30: Short term msd 29.771610. Long term msd 29.950108
# [01/19/2018 02:33:20 INFO 140719683082048 algo.py:451] Iter 40: Short term msd 29.119347. Long term msd 29.335317
# Arguments: train
# [01/19/2018 02:33:16 INFO 140393686591296 integration.py:222] Reading default configuration from /opt/amazon/lib/python2.7/site-packages/algorithm/default-input.json: {u'_num_gpus': u'auto', u'local_lloyd_num_trials': u'auto', u'_log_level': u'info', u'_kvstore': u'auto', u'local_lloyd_init_method': u'kmeans++', u'force_dense': u'true', u'epochs': u'1', u'init_method': u'random', u'local_lloyd_tol': u'0.0001', u'local_lloyd_max_iter': u'300', u'_disable_wait_to_read': u'false', u'extra_center_factor': u'auto', u'eval_metrics': u'["msd"]', u'_num_kv_servers': u'1', u'mini_batch_size': u'5000', u'half_life_time_size': u'0', u'_num_slices': u'1'}
# [01/19/2018 02:33:16 INFO 140393686591296 integration.py:228] Reading provided configuration from /opt/ml/input/config/hyperparameters.json: {u'feature_dim': u'784', u'mini_batch_size': u'500', u'k': u'10', u'force_dense': u'True'}
# [01/19/2018 02:33:16 INFO 140393686591296 integration.py:244] Final configuration: {u'k': u'10', u'_num_gpus': u'auto', u'local_lloyd_num_trials': u'auto', u'_log_level': u'info', u'_kvstore': u'auto', u'local_lloyd_init_method': u'kmeans++', u'force_dense': u'True', u'epochs': u'1', u'init_method': u'random', u'feature_dim': u'784', u'local_lloyd_tol': u'0.0001', u'local_lloyd_max_iter': u'300', u'_disable_wait_to_read': u'false', u'extra_center_factor': u'auto', u'eval_metrics': u'["msd"]', u'_num_kv_servers': u'1', u'mini_batch_size': u'500', u'half_life_time_size': u'0', u'_num_slices': u'1'}
# [01/19/2018 02:33:18 INFO 140393686591296 utils.py:134] Environment: {'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'DMLC_PS_ROOT_PORT': '9000', 'DMLC_NUM_WORKER': '2', 'SAGEMAKER_HTTP_PORT': '8080', 'HOME': '/root', 'PYTHONUNBUFFERED': 'TRUE', 'CANONICAL_ENVROOT': '/opt/amazon', 'LD_LIBRARY_PATH': '/opt/amazon/lib:/usr/local/nvidia/lib64:/opt/amazon/lib/stubs', 'MXNET_KVSTORE_BIGARRAY_BOUND': '400000000', 'LANG': 'en_US.utf8', 'DMLC_INTERFACE': 'ethwe', 'SHLVL': '1', 'DMLC_PS_ROOT_URI': '10.32.0.4', 'AWS_REGION': 'us-east-1', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/amazon/bin:/opt/amazon/bin', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'ENVROOT': '/opt/amazon', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'OMP_NUM_THREADS': '18', 'HOSTNAME': 'aws', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/2ede2b8d-0402-4642-b3b8-3f4839a52605', 'DMLC_ROLE': 'worker', 'PWD': '/', 'DMLC_NUM_SERVER': '1'}
# [01/19/2018 02:33:18 INFO 140393686591296 train.py:72] Using default worker.
# [01/19/2018 02:33:19 INFO 140393686591296 data_handler_factory.py:79] Loaded iterator creator application/x-recordio-protobuf for content type ('application/x-recordio-protobuf', '1.0')
# [01/19/2018 02:33:19 INFO 140393686591296 sdk.py:138] Create Store: dist_async
# [01/19/2018 02:33:19 INFO 140393686591296 gpu.py:44] nvidia-smi took: 0.0252618789673 secs to identify 0 gpus
# [01/19/2018 02:33:19 INFO 140393686591296 sdk.py:85] Number of GPUs being used: 0
# [01/19/2018 02:33:19 INFO 140393686591296 algo.py:282] Setting up with params: {u'k': u'10', u'_num_gpus': u'auto', u'local_lloyd_num_trials': u'auto', u'_log_level': u'info', u'_kvstore': u'auto', u'local_lloyd_init_method': u'kmeans++', u'force_dense': u'True', u'epochs': u'1', u'init_method': u'random', u'feature_dim': u'784', u'local_lloyd_tol': u'0.0001', u'local_lloyd_max_iter': u'300', u'_disable_wait_to_read': u'false', u'extra_center_factor': u'auto', u'eval_metrics': u'["msd"]', u'_num_kv_servers': u'1', u'mini_batch_size': u'500', u'half_life_time_size': u'0', u'_num_slices': u'1'}
# /opt/amazon/lib/python2.7/site-packages/ai_algorithms_sdk/config/config_helper.py:180: DeprecationWarning: deprecated
#   warnings.warn("deprecated", DeprecationWarning)
# /opt/amazon/lib/python2.7/site-packages/ai_algorithms_sdk/config/config_helper.py:125: DeprecationWarning: deprecated
#   warnings.warn("deprecated", DeprecationWarning)
# [01/19/2018 02:33:19 INFO 140393686591296 sdk.py:85] Number of GPUs being used: 0
# [01/19/2018 02:33:19 INFO 140393686591296 algo.py:320] number of center slices 1
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 1, "sum": 1.0, "min": 1}, "Number of Batches Since Last Reset": {"count": 1, "max": 1, "sum": 1.0, "min": 1}, "Number of Records Since Last Reset": {"count": 1, "max": 500, "sum": 500.0, "min": 500}, "Total Batches Seen": {"count": 1, "max": 1, "sum": 1.0, "min": 1}, "Total Records Seen": {"count": 1, "max": 500, "sum": 500.0, "min": 500}, "Max Records Seen Between Resets": {"count": 1, "max": 500, "sum": 500.0, "min": 500}, "Reset Count": {"count": 1, "max": 0, "sum": 0.0, "min": 0}}, "EndTime": 1516329199.918472, "Dimensions": {"Host": "algo-2", "Meta": "init_train_data_iter", "Operation": "training", "Algorithm": "AWS/KMeansWebscale"}, "StartTime": 1516329199.918443}
#
# [01/19/2018 02:33:20 INFO 140393686591296 algo.py:451] Iter 10: Short term msd 31.748452. Long term msd 33.342257
# [01/19/2018 02:33:20 INFO 140393686591296 algo.py:451] Iter 20: Short term msd 29.252411. Long term msd 30.189568
# [01/19/2018 02:33:20 INFO 140393686591296 algo.py:451] Iter 30: Short term msd 29.265802. Long term msd 29.649440
# [01/19/2018 02:33:20 INFO 140393686591296 algo.py:451] Iter 40: Short term msd 28.710958. Long term msd 28.983095
# [01/19/2018 02:33:20 INFO 140393686591296 algo.py:390] processed a total of 25000 examples
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 50, "sum": 50.0, "min": 50}, "Number of Batches Since Last Reset": {"count": 1, "max": 50, "sum": 50.0, "min": 50}, "Number of Records Since Last Reset": {"count": 1, "max": 25000, "sum": 25000.0, "min": 25000}, "Total Batches Seen": {"count": 1, "max": 51, "sum": 51.0, "min": 51}, "Total Records Seen": {"count": 1, "max": 25500, "sum": 25500.0, "min": 25500}, "Max Records Seen Between Resets": {"count": 1, "max": 25000, "sum": 25000.0, "min": 25000}, "Reset Count": {"count": 1, "max": 1, "sum": 1.0, "min": 1}}, "EndTime": 1516329200.768283, "Dimensions": {"Host": "algo-2", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/KMeansWebscale", "epoch": 0}, "StartTime": 1516329200.768198}
#
# [01/19/2018 02:33:20 INFO 140393686591296 algo.py:792] shrinking 100 centers into 10
# [01/19/2018 02:33:20 INFO 140393686591296 kmeans_routines.py:174] local kmeans attempt #0. Current mean square distance 11.522316
# [01/19/2018 02:33:20 INFO 140393686591296 kmeans_routines.py:174] local kmeans attempt #1. Current mean square distance 12.079576
# [01/19/2018 02:33:20 INFO 140393686591296 kmeans_routines.py:174] local kmeans attempt #2. Current mean square distance 11.732128
# [01/19/2018 02:33:20 INFO 140393686591296 kmeans_routines.py:174] local kmeans attempt #3. Current mean square distance 11.913443
# [01/19/2018 02:33:20 INFO 140393686591296 kmeans_routines.py:174] local kmeans attempt #4. Current mean square distance 11.655721
# [01/19/2018 02:33:20 INFO 140393686591296 kmeans_routines.py:174] local kmeans attempt #5. Current mean square distance 12.053100
# [01/19/2018 02:33:20 INFO 140719683082048 algo.py:390] processed a total of 25000 examples
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 50, "sum": 50.0, "min": 50}, "Number of Batches Since Last Reset": {"count": 1, "max": 50, "sum": 50.0, "min": 50}, "Number of Records Since Last Reset": {"count": 1, "max": 25000, "sum": 25000.0, "min": 25000}, "Total Batches Seen": {"count": 1, "max": 51, "sum": 51.0, "min": 51}, "Total Records Seen": {"count": 1, "max": 25500, "sum": 25500.0, "min": 25500}, "Max Records Seen Between Resets": {"count": 1, "max": 25000, "sum": 25000.0, "min": 25000}, "Reset Count": {"count": 1, "max": 1, "sum": 1.0, "min": 1}}, "EndTime": 1516329200.711422, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/KMeansWebscale", "epoch": 0}, "StartTime": 1516329200.711377}
#
# [01/19/2018 02:33:20 INFO 140719683082048 algo.py:792] shrinking 100 centers into 10
# [01/19/2018 02:33:20 INFO 140719683082048 kmeans_routines.py:174] local kmeans attempt #0. Current mean square distance 11.517241
# [01/19/2018 02:33:20 INFO 140719683082048 kmeans_routines.py:174] local kmeans attempt #1. Current mean square distance 12.183386
# [01/19/2018 02:33:20 INFO 140719683082048 kmeans_routines.py:174] local kmeans attempt #2. Current mean square distance 11.654158
# [01/19/2018 02:33:20 INFO 140719683082048 kmeans_routines.py:174] local kmeans attempt #3. Current mean square distance 12.006767
# [01/19/2018 02:33:20 INFO 140719683082048 kmeans_routines.py:174] local kmeans attempt #4. Current mean square distance 11.647963
# [01/19/2018 02:33:20 INFO 140719683082048 kmeans_routines.py:174] local kmeans attempt #5. Current mean square distance 12.043166
# [01/19/2018 02:33:20 INFO 140719683082048 kmeans_routines.py:174] local kmeans attempt #6. Current mean square distance 11.939414
# [01/19/2018 02:33:20 INFO 140719683082048 kmeans_routines.py:174] local kmeans attempt #7. Current mean square distance 11.682574
# [01/19/2018 02:33:21 INFO 140719683082048 kmeans_routines.py:174] local kmeans attempt #8. Current mean square distance 11.450267
# [01/19/2018 02:33:21 INFO 140719683082048 kmeans_routines.py:174] local kmeans attempt #9. Current mean square distance 11.664266
# [01/19/2018 02:33:21 INFO 140719683082048 algo.py:800] finished shrinking process. Mean Square Distance = 11
# [01/19/2018 02:33:21 INFO 140719683082048 timer.py:33] compute all data-center distances: point norm took: 27.4297%, (0.219856 secs)
# [01/19/2018 02:33:21 INFO 140719683082048 timer.py:33] gradient: cluster center took: 17.3648%, (0.139183 secs)
# [01/19/2018 02:33:21 INFO 140719683082048 timer.py:33] batch data loading with context took: 14.4137%, (0.115530 secs)
# [01/19/2018 02:33:21 INFO 140719683082048 timer.py:33] compute all data-center distances: inner product took: 12.3861%, (0.099278 secs)
# [01/19/2018 02:33:21 INFO 140719683082048 timer.py:33] compute all data-center distances: center norm took: 6.8387%, (0.054814 secs)
# [01/19/2018 02:33:21 INFO 140719683082048 timer.py:33] collect from kv store took: 6.3952%, (0.051259 secs)
# [01/19/2018 02:33:21 INFO 140719683082048 timer.py:33] predict compute msd took: 6.2309%, (0.049942 secs)
# [01/19/2018 02:33:21 INFO 140719683082048 timer.py:33] gradient: cluster size  took: 4.0281%, (0.032286 secs)
# [01/19/2018 02:33:21 INFO 140719683082048 timer.py:33] gradient: one_hot took: 2.4629%, (0.019741 secs)
# [01/19/2018 02:33:21 INFO 140719683082048 timer.py:33] update state and report convergance took: 1.3443%, (0.010775 secs)
# [01/19/2018 02:33:21 INFO 140719683082048 timer.py:33] splitting centers key-value pair took: 0.9566%, (0.007668 secs)
# [01/19/2018 02:33:21 INFO 140719683082048 timer.py:33] predict minus dist took: 0.1186%, (0.000950 secs)
# [01/19/2018 02:33:21 INFO 140719683082048 timer.py:33] update set-up time took: 0.0303%, (0.000243 secs)
# [01/19/2018 02:33:21 INFO 140719683082048 timer.py:35] TOTAL took: 0.801524400711
# [01/19/2018 02:33:21 INFO 140719683082048 sdk.py:85] Number of GPUs being used: 0
# #metrics {"Metrics": {"finalize.time": {"count": 1, "max": 279.940128326416, "sum": 279.940128326416, "min": 279.940128326416}, "initialize.time": {"count": 1, "max": 13.271093368530273, "sum": 13.271093368530273, "min": 13.271093368530273}, "model.serialize.time": {"count": 1, "max": 0.3070831298828125, "sum": 0.3070831298828125, "min": 0.3070831298828125}, "update.time": {"count": 1, "max": 804.2550086975098, "sum": 804.2550086975098, "min": 804.2550086975098}, "epochs": {"count": 1, "max": 1, "sum": 1.0, "min": 1}, "state.serialize.time": {"count": 1, "max": 0.47397613525390625, "sum": 0.47397613525390625, "min": 0.47397613525390625}, "_shrink.time": {"count": 1, "max": 276.6449451446533, "sum": 276.6449451446533, "min": 276.6449451446533}}, "EndTime": 1516329201.038234, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "AWS/KMeansWebscale"}, "StartTime": 1516329199.880937}
#
# [01/19/2018 02:33:21 INFO 140719683082048 train.py:191] Test data was not provided.
# #metrics {"Metrics": {"totaltime": {"count": 1, "max": 4017.764091491699, "sum": 4017.764091491699, "min": 4017.764091491699}, "setuptime": {"count": 1, "max": 1524.9261856079102, "sum": 1524.9261856079102, "min": 1524.9261856079102}}, "EndTime": 1516329201.039914, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "AWS/KMeansWebscale"}, "StartTime": 1516329201.038329}
#
# [01/19/2018 02:33:20 INFO 140393686591296 kmeans_routines.py:174] local kmeans attempt #6. Current mean square distance 11.381282
# [01/19/2018 02:33:21 INFO 140393686591296 kmeans_routines.py:174] local kmeans attempt #7. Current mean square distance 11.415558
# [01/19/2018 02:33:21 INFO 140393686591296 kmeans_routines.py:174] local kmeans attempt #8. Current mean square distance 11.574092
# [01/19/2018 02:33:21 INFO 140393686591296 kmeans_routines.py:174] local kmeans attempt #9. Current mean square distance 11.040415
# [01/19/2018 02:33:21 INFO 140393686591296 algo.py:800] finished shrinking process. Mean Square Distance = 11
# [01/19/2018 02:33:21 INFO 140393686591296 timer.py:33] compute all data-center distances: point norm took: 25.5897%, (0.216612 secs)
# [01/19/2018 02:33:21 INFO 140393686591296 timer.py:33] gradient: cluster center took: 16.4101%, (0.138909 secs)
# [01/19/2018 02:33:21 INFO 140393686591296 timer.py:33] collect from kv store took: 12.3606%, (0.104630 secs)
# [01/19/2018 02:33:21 INFO 140393686591296 timer.py:33] batch data loading with context took: 12.3430%, (0.104481 secs)
# [01/19/2018 02:33:21 INFO 140393686591296 timer.py:33] compute all data-center distances: inner product took: 12.2051%, (0.103314 secs)
# [01/19/2018 02:33:21 INFO 140393686591296 timer.py:33] compute all data-center distances: center norm took: 7.5444%, (0.063862 secs)
# [01/19/2018 02:33:21 INFO 140393686591296 timer.py:33] predict compute msd took: 5.9401%, (0.050282 secs)
# [01/19/2018 02:33:21 INFO 140393686591296 timer.py:33] gradient: cluster size  took: 3.9669%, (0.033579 secs)
# [01/19/2018 02:33:21 INFO 140393686591296 timer.py:33] update state and report convergance took: 1.8096%, (0.015318 secs)
# [01/19/2018 02:33:21 INFO 140393686591296 timer.py:33] splitting centers key-value pair took: 0.8534%, (0.007224 secs)
# [01/19/2018 02:33:21 INFO 140393686591296 timer.py:33] gradient: one_hot took: 0.8511%, (0.007205 secs)
# [01/19/2018 02:33:21 INFO 140393686591296 timer.py:33] predict minus dist took: 0.1063%, (0.000900 secs)
# [01/19/2018 02:33:21 INFO 140393686591296 timer.py:33] update set-up time took: 0.0197%, (0.000167 secs)
# [01/19/2018 02:33:21 INFO 140393686591296 timer.py:35] TOTAL took: 0.846481800079
# [01/19/2018 02:33:21 INFO 140393686591296 sdk.py:85] Number of GPUs being used: 0
# [01/19/2018 02:33:21 INFO 140393686591296 algo.py:44] No model is serialized on a non-master node
# #metrics {"Metrics": {"finalize.time": {"count": 1, "max": 302.5979995727539, "sum": 302.5979995727539, "min": 302.5979995727539}, "initialize.time": {"count": 1, "max": 13.616085052490234, "sum": 13.616085052490234, "min": 13.616085052490234}, "model.serialize.time": {"count": 1, "max": 0.21505355834960938, "sum": 0.21505355834960938, "min": 0.21505355834960938}, "update.time": {"count": 1, "max": 849.5140075683594, "sum": 849.5140075683594, "min": 849.5140075683594}, "epochs": {"count": 1, "max": 1, "sum": 1.0, "min": 1}, "state.serialize.time": {"count": 1, "max": 0.40602684020996094, "sum": 0.40602684020996094, "min": 0.40602684020996094}, "_shrink.time": {"count": 1, "max": 300.11701583862305, "sum": 300.11701583862305, "min": 300.11701583862305}}, "EndTime": 1516329201.072095, "Dimensions": {"Host": "algo-2", "Operation": "training", "Algorithm": "AWS/KMeansWebscale"}, "StartTime": 1516329199.892398}
#
# [01/19/2018 02:33:21 INFO 140393686591296 train.py:191] Test data was not provided.
# #metrics {"Metrics": {"totaltime": {"count": 1, "max": 4403.2580852508545, "sum": 4403.2580852508545, "min": 4403.2580852508545}, "setuptime": {"count": 1, "max": 2022.8500366210938, "sum": 2022.8500366210938, "min": 2022.8500366210938}}, "EndTime": 1516329201.073807, "Dimensions": {"Host": "algo-2", "Operation": "training", "Algorithm": "AWS/KMeansWebscale"}, "StartTime": 1516329201.072186}
# ===== Job Complete =====
# CPU times: user 20.6 s, sys: 804 ms, total: 21.4 s
# Wall time: 7min 5s

# %%
# %%time

kmeans_predictor = kmeans.deploy(initial_instance_count=1,
                                 instance_type='ml.m4.xlarge')
# Out:
# INFO:sagemaker:Creating model with name: kmeans-2018-01-19-02-37-21-844
# INFO:sagemaker:Creating endpoint with name kmeans-2018-01-19-02-27-34-273
# ---------------------------------------------------------------------------------------------------------------------------------------!CPU times: user 524 ms, sys: 44 ms, total: 568 ms
# Wall time: 11min 30s

# %%
result = kmeans_predictor.predict(train_set[0][34:35])
print(result)
# Out:
# [label {
#   key: "closest_cluster"
#   value {
#     float32_tensor {
#       values: 2.0
#     }
#   }
# }
# label {
#   key: "distance_to_cluster"
#   value {
#     float32_tensor {
#       values: 7.002975940704346
#     }
#   }
# }
# ]

# %%
# %%time 

result = kmeans_predictor.predict(valid_set[0][0:100])
clusters = [r.label['closest_cluster'].float32_tensor.values[0] for r in result]
# Out:
# CPU times: user 24 ms, sys: 0 ns, total: 24 ms
# Wall time: 223 ms

# %%
for cluster in range(10):
    print('\n\n\nCluster {}:'.format(int(cluster)))
    digits = [ img for l, img in zip(clusters, valid_set[0]) if int(l) == cluster ]
    height=((len(digits)-1)//5)+1
    width=5
    plt.rcParams["figure.figsize"] = (width,height)
    _, subplots = plt.subplots(height, width)
    subplots=numpy.ndarray.flatten(subplots)
    for subplot, image in zip(subplots, digits):
        show_digit(image, subplot=subplot)
    for subplot in subplots[len(digits):]:
        subplot.axis('off')

    plt.show()
# Out:
# Cluster 0:
# Cluster 1:
# Cluster 2:
# Cluster 3:
# Cluster 4:
# Cluster 5:
# Cluster 6:
# Cluster 7:
# Cluster 8:
# Cluster 9:
